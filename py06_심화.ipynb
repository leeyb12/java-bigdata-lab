# %% [markdown]
# # 심화

# %% [markdown]
# ## 클래스

# %%
# 불편한 코드
result1 = 0
result2 = 0

def add1(num):
    global result1
    result1 += num
    return result1

def add2(num):
    global result2
    result2 += num
    return result2

# %%
# 클래스 사용

class Cal:
    def add(num):
